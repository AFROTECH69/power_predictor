# %%
import streamlit as st
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

# %%
# Load the data
data = pd.read_csv('combined_output.csv')

# Load the model
with open('src/randomforest_regression_model.pkl', 'rb') as f:
    model = pickle.load(f)

# %%
# Load the model
with open('x_scaler.pkl', 'rb') as f:
    scaler_x = pickle.load(f)

# %%
data
# Out:
#       id        pf     voltage       power   current     energy        task  \
# 0      0  0.907454  234.610302  234.046002  1.099334  58.511501  Inspection
# 1      1  0.850641  226.717015  214.814209  1.113865  53.703552  Inspection
# 2      2  0.984855  228.623872  226.119463  1.004256  56.529866  Inspection
# 3      3  0.865841  234.261008  228.060387  1.124376  57.015097  Inspection
# 4      4  0.860810  225.178685  234.805600  1.211361  58.701400  Inspection
# ...   ..       ...         ...         ...       ...        ...         ...
# 1531  91  0.987473  231.846715  149.174216  0.651580  37.293554        idle
# 1532  92  0.814335  227.182783  155.247232  0.839161  38.811808        idle
# 1533  93  0.883988  227.166594  176.337076  0.878118  44.084269        idle
# 1534  94  0.821047  228.866654  163.818047  0.871789  40.954512        idle
# 1535  95  0.838760  232.904691  179.998629  0.921411  44.999657        idle
#
#      job_type         timestamp
# 0       robot  2024_07_19_20_00
# 1       robot  2024_07_19_20_15
# 2       robot  2024_07_19_20_30
# 3       robot  2024_07_19_20_45
# 4       robot  2024_07_19_21_00
# ...       ...               ...
# 1531   manual  2024_07_20_18_45
# 1532   manual  2024_07_20_19_00
# 1533   manual  2024_07_20_19_15
# 1534   manual  2024_07_20_19_30
# 1535   manual  2024_07_20_19_45
#
# [1536 rows x 9 columns]

# %%
# Convert 'timestamp' column to datetime (adjust the format according to your actual data)
data['timestamp'] = pd.to_datetime(data['timestamp'], format='%Y-%m-%d-%H-%M')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1536 entries, 0 to 1535
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         1536 non-null   int64
#  1   pf         1536 non-null   float64
#  2   voltage    1536 non-null   float64
#  3   power      1536 non-null   float64
#  4   current    1536 non-null   float64
#  5   energy     1536 non-null   float64
#  6   task       1536 non-null   object
#  7   job_type   1536 non-null   object
#  8   timestamp  1536 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(5), int64(1), object(2)
# memory usage: 108.1+ KB

# %%
# Out:
# /tmp/ipykernel_62819/2938215414.py:29: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 53
#      50     st.write(f"Root Mean Squared Error (RMSE):")
#      52 if __name__ == '__main__':
# ---> 53     st.run()
#
# AttributeError: module 'streamlit' has no attribute 'run'
